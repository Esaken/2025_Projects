# %%
import os
import shutil
import hashlib
from datetime import datetime

# %%
def get_file_hash(file_path):
    """Calculate the SHA-256 hash of a file."""
    with open(file_path, 'rb') as f:
        return hashlib.sha256(f.read()).hexdigest()

def organize_by_date_and_extension(folder_path):
    """Organize files by date, then by extension, and handle duplicates."""
    # Create a "Duplicates" folder at the root directory
    duplicates_folder = os.path.join(folder_path, '_Duplicates')
    os.makedirs(duplicates_folder, exist_ok=True)

    # Dictionary to store file hashes for duplicate detection
    file_hashes = {}

    # Iterate over all files in the directory
    all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    for file_path in all_files:
        # Get the modification date of the file
        modification_time = os.path.getmtime(file_path)
        modification_date = datetime.fromtimestamp(modification_time).strftime('%Y-%m-%d')

        # Create a folder for the modification date if it doesn't exist
        date_folder = os.path.join(folder_path, modification_date)
        os.makedirs(date_folder, exist_ok=True)

        # Calculate the file hash
        file_hash = get_file_hash(file_path)

        # Check for duplicates
        if file_hash in file_hashes:
            # File is a duplicate, move to "Duplicates" folder
            shutil.move(file_path, os.path.join(duplicates_folder, os.path.basename(file_path)))
            print(f"Moved duplicate file {os.path.basename(file_path)} to Duplicates folder.")
        else:
            # Store the file hash to prevent future duplicates
            file_hashes[file_hash] = file_path

            # Move the file to the date folder
            new_path = os.path.join(date_folder, os.path.basename(file_path))
            shutil.move(file_path, new_path)

            # Organize files within the date folder by extension
            _, extension = os.path.splitext(new_path)
            extension = extension.lower()
            extension_folder = os.path.join(date_folder, extension[1:])  # Remove the dot from extension
            os.makedirs(extension_folder, exist_ok=True)

            # Move the file to its extension-specific folder
            shutil.move(new_path, os.path.join(extension_folder, os.path.basename(new_path)))
            print(f"Moved {os.path.basename(new_path)} to {extension_folder}.")

    print("Files organized by date, extension, and duplicates handled successfully!")

if __name__ == "__main__":
    # Specify the directory to organize
    folder_path = input("Enter the path to the folder to organize: ")
    organize_by_date_and_extension(folder_path)
# Out:
# Enter the path to the folder to organize:  C:\Users\IT Baron Capital\Downloads
# Moved 1737616161707.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-23\jpeg.
# Moved 1737635565144.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-23\jpeg.
# Moved 1737637036108.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-23\jpeg.
# Moved 1738306139057.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738329525254 (1).jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved duplicate file 1738329525254.jpeg to Duplicates folder.
# Moved 1738329558704.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738329571892.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738329649367.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738329668808.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738331561496.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738331894458.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved 1738394600352.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-01\jpeg.
# Moved 1738394625081.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-01\jpeg.
# Moved 1738588460740.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-03\jpeg.
# Moved 1738588581131 (1).jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-03\jpeg.
# Moved duplicate file 1738588581131.jpeg to Duplicates folder.
# Moved 1738753169706.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-05\jpeg.
# Moved 1738926887827 (1).jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-07\jpeg.
# Moved duplicate file 1738926887827.jpeg to Duplicates folder.
# Moved 1739251672979.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-11\jpeg.
# Moved 1739252563169.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-11\jpeg.
# Moved 572-collagen_ing_h300.jpg to C:\Users\IT Baron Capital\Downloads\2025-02-11\jpg.
# Moved 809778714249592v.mp4 to C:\Users\IT Baron Capital\Downloads\2025-01-31\mp4.
# Moved 986730733188903v.mp4 to C:\Users\IT Baron Capital\Downloads\2025-01-23\mp4.
# Moved Advanced_IP_Scanner_2.5.4594.1.exe to C:\Users\IT Baron Capital\Downloads\2025-02-05\exe.
# Moved All Cheat Sheets.pdf to C:\Users\IT Baron Capital\Downloads\2025-02-12\pdf.
# Moved Anaconda3-2024.10-1-Windows-x86_64.exe to C:\Users\IT Baron Capital\Downloads\2025-01-28\exe.
# Moved AnyDesk.exe to C:\Users\IT Baron Capital\Downloads\2025-01-20\exe.
# Moved Ask_the_Experts_Session.ics to C:\Users\IT Baron Capital\Downloads\2025-01-25\ics.
# Moved Baron.xls to C:\Users\IT Baron Capital\Downloads\2025-02-13\xls.
# Moved cerave_1738306101388.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved cerave_1738306107898.jpeg to C:\Users\IT Baron Capital\Downloads\2025-01-31\jpeg.
# Moved Chinese Scholarships 2025 final (1).pdf to C:\Users\IT Baron Capital\Downloads\2025-02-04\pdf.
# Moved Data Migration Specialist - JD.pdf (1).pdf to C:\Users\IT Baron Capital\Downloads\2025-02-04\pdf.
# Moved desktop.ini to C:\Users\IT Baron Capital\Downloads\2024-10-04\ini.
# Moved Feasibility Report -Template.docx to C:\Users\IT Baron Capital\Downloads\2025-02-10\docx.
# Moved Git-2.47.1.2-64-bit.exe to C:\Users\IT Baron Capital\Downloads\2025-02-03\exe.
# Moved invoice (1).pdf to C:\Users\IT Baron Capital\Downloads\2025-02-12\pdf.
# Moved invoice.pdf to C:\Users\IT Baron Capital\Downloads\2025-02-12\pdf.
# Moved ipscan-3.9.1-setup.exe to C:\Users\IT Baron Capital\Downloads\2025-02-10\exe.
# Moved KAT079W SEARCH.pdf to C:\Users\IT Baron Capital\Downloads\2025-02-05\pdf.
# Moved Kenya’s Boy-Child Crisis. (1).pdf to C:\Users\IT Baron Capital\Downloads\2025-02-08\pdf.
# Moved duplicate file Kenya’s Boy-Child Crisis..pdf to Duplicates folder.
# Moved larocheposay_1738906728339.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-07\jpeg.
# Moved duplicate file larocheposay_1738906887844.jpeg to Duplicates folder.
# Moved larocheposay_1738906939015.jpeg to C:\Users\IT Baron Capital\Downloads\2025-02-07\jpeg.
# Moved duplicate file larocheposay_1738907498558.jpeg to Duplicates folder.
# Moved Qwako Suite Brochure Jan 2025_250204_224837.pdf to C:\Users\IT Baron Capital\Downloads\2025-02-05\pdf.
# Moved Radmin_3.5.2.1_EN.zip to C:\Users\IT Baron Capital\Downloads\2025-02-05\zip.
# Moved RangeChem-New-Logo-transparent (1).png to C:\Users\IT Baron Capital\Downloads\2025-01-31\png.
# Moved Security-Operations-Assistant-Feb-2025.pdf to C:\Users\IT Baron Capital\Downloads\2025-01-31\pdf.
# Files organized by date, extension, and duplicates handled successfully!
